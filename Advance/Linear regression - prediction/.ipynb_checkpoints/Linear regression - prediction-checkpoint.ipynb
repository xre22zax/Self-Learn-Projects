# %% [markdown]
# Linear Regression is when you have a group of points on a graph, and you find a line that approximately resembles that group of points. A good Linear Regression algorithm minimizes the error, or the distance from each point to the line. A line with the least error is the line that fits the data the best. We call this a line of best fit.

# %%
# Load libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm

# Read in the data
website = pd.read_csv('website.csv')

# Print the first five rows
print(website.head())
# Out:
#    time_seconds   age browser
# 0         486.0  47.1  Safari
# 1         645.7  64.6  Chrome
# 2         345.0  45.4  Safari
# 3         413.4  34.4  Chrome
# 4         426.4  31.3  Safari

# %%
# Create a scatter plot of time vs age
plt.scatter(website.age, website.time_seconds)

# Show then clear plot
plt.show()
plt.clf()

# %% [markdown]
# 1. Building a Linear Regression Model:
#
#     - model = sm.OLS.from_formula('time_seconds ~ age', website):
#     - Creates a linear regression model using the statsmodels library (sm).
#     - OLS stands for Ordinary Least Squares, a common method for fitting linear models.
#     - from_formula specifies the model's formula: time_seconds ~ age means you're predicting time_seconds based on age.
#     - website is likely a pandas DataFrame containing the data for time_seconds and age.
#
# </br>
# 2. Fitting the Model:
#
#     - results = model.fit():
#     - Fits the model to the data, meaning it finds the best line that describes the relationship between time_seconds and age.
#     - print(results.params):
#     - Prints the estimated parameters (coefficients) of the model:
#     - Intercept: The value of time_seconds when age is 0.
#     - age: The change in time_seconds associated with a 1-unit increase in age.
#
# </br>
# 3. Visualizing the Model:
#
#     - plt.scatter(website.age, website.time_seconds):
#     - Creates a scatter plot showing the individual data points (age and time_seconds).
#     - plt.plot(website.age, results.params[0] + results.params[1]*website.age):
#     - Overlays the fitted regression line on top of the scatter plot.

# %%
# Fit a linear regression to predict time_seconds based on age
model = sm.OLS.from_formula('time_seconds ~ age', website)

# Fit the model
results = model.fit()
print(results.params)

# Plot the scatter plot with the line on top
plt.scatter(website.age, website.time_seconds)
plt.plot(website.age, results.params[0] + results.params[1]*website.age)

plt.xlabel('Age')
plt.ylabel('Time (s)')
plt.title('Predict time for diffrent ages')

# Show then clear plot
plt.show()
plt.clf()
# Out:
# Intercept    128.967945
# age            6.913758
# dtype: float64
# C:\Users\xre22\AppData\Local\Temp\ipykernel_8428\907673339.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.plot(website.age, results.params[0] + results.params[1]*website.age)

# %% [markdown]
# 1. Calculating Fitted Values:
#
#     - fitted_values = results.predict(website):
#     - Uses the fitted linear regression model (results) to generate predicted values of time_seconds for each observation in the website dataset.
#     - These predicted values represent the values that the model "expects" based on the relationship it has learned between time_seconds and age.
# </br>
# 2. Calculating Residuals:
#
#     - residuals = website.time_seconds - fitted_values:
#     - Subtracts the predicted values (fitted_values) from the actual observed values (website.time_seconds) to create residuals.
#     - Residuals are the differences between the model's predictions and the actual data. They indicate how well the model fits the data.
# </br>
# 3. Checking Normality Assumption:
#
#     - plt.hist(residuals):
#     - Creates a histogram of the residuals to visualize their distribution.
#     - This is a crucial diagnostic for linear regression because it assumes that the residuals are normally distributed.

# %%
# Calculate fitted values
fitted_values = results.predict(website)

# Calculate residuals
residuals = website.time_seconds - fitted_values

# Check normality assumption
plt.hist(residuals)

plt.xlabel('Residuals')
plt.ylabel('Observations')
plt.title('Observed time VS Predicted time')

# Show then clear the plot
plt.show()
plt.clf()

# %%
# Normal distribution
plt.hist(website.time_seconds)

plt.show()
plt.clf()

# %% [markdown]
# Homoscedasticity assumption tells us that theres no equal or similar variances in fitted_values and residuals.

# %%
# Check homoscedasticity assumption
plt.scatter(fitted_values, residuals)

# Show then clear the plot
plt.show()
plt.clf()

# %% [markdown]
# 1. Prediction for 40-Year-Old:
#
#     - pred40 = results.params[0] + results.params[1]*40:
#         - Uses the fitted linear regression model from a previous step to predict the time_seconds for a 40-year-old.
#         - It does this by plugging 40 into the model's equation (intercept + slope * age).
#     - print('predicted time on website for a 40 year old: ', pred40):
#         - Prints the predicted time on the website for a 40-year-old.
#
# </br>
# 2. Linear Regression with Browser:
#
#     - model = sm.OLS.from_formula('time_seconds ~ browser', website):
#         - Creates a new linear regression model to examine the relationship between time_seconds and browser type.
#     - results = model.fit():
#         - Fits this model to the website dataset.
#     - print(results.params):
#         - Prints the model's parameters (coefficients) for each browser.
# </br>
# 3. Group Mean Comparisons:
#
#     - mean_time_chrome = np.mean(website.time_seconds[website.browser == 'Chrome']):
#         - Calculates the mean time_seconds for users using the Chrome browser.
#     - mean_time_safari = np.mean(website.time_seconds[website.browser == 'Safari']):
#         - Calculates the mean time_seconds for users using the Safari browser.
#     - Print statements:
#         - Prints the calculated mean times for each browser and their difference.
# </br>
# ** Summary: **
#
# 1. The code performs two main analyses:
#
# 2. Predicts the time on the website for a 40-year-old using a previously fitted linear regression model based on age. Explores the relationship between time on the website and browser type using a new linear regression model and compares the mean times for Chrome and Safari users.

# %%
# Predict amount of time on website for 40 year old
pred40 = results.params[0] + results.params[1]*40
print('predicted time on website for a 40 year old: ', pred40)

# Fit a linear regression to predict time_seconds based on age
model = sm.OLS.from_formula('time_seconds ~ browser', website)
results = model.fit()
print(results.params)

# Calculate and print the group means (for comparison)
mean_time_chrome = np.mean(website.time_seconds[website.browser == 'Chrome'])
mean_time_safari = np.mean(website.time_seconds[website.browser == 'Safari'])
print('Mean time (Chrome): ', mean_time_chrome)
print('Mean time (Safari): ', mean_time_safari)
print('Mean time difference: ', mean_time_chrome - mean_time_safari)
# Out:
# predicted time on website for a 40 year old:  405.51824893244975
# Intercept            489.704255
# browser[T.Safari]    -99.057086
# dtype: float64
# Mean time (Chrome):  489.70425531914884
# Mean time (Safari):  390.64716981132074
# Mean time difference:  99.0570855078281
